# %%
import pandas as pd
import plotly

# %%
life=pd.read_csv('data/life.csv')
money=pd.read_csv('data/money.csv')
happines=pd.read_csv('data/happines2022.csv')
work=pd.read_csv('data/work.csv')
master = pd.read_csv('data/master.csv')

# %%
master

# %%
life
# Out:
#      Country name ISO3  year  Healthy life expectancy at birth
# 0     Afghanistan  AFG  2017                            53.250
# 1     Afghanistan  AFG  2018                            53.575
# 2     Afghanistan  AFG  2019                            53.900
# 3     Afghanistan  AFG  2021                            54.550
# 4     Afghanistan  AFG  2022                            54.875
# ...           ...  ...   ...                               ...
# 2190     Tanzania  TZA  2016                            57.150
# 2191     Tanzania  TZA  2009                            52.740
# 2192     Tanzania  TZA  2010                            53.400
# 2193        Syria  SYR  2012                            61.580
# 2194        Syria  SYR  2013                            59.820
#
# [2195 rows x 4 columns]

# %%
money
# Out:
#      ISO3 INDICATOR SUBJECT MEASURE FREQUENCY  year     money  Flag Codes
# 0     AUS    AVWAGE     TOT     USD         A  1990  42490.02         NaN
# 1     AUS    AVWAGE     TOT     USD         A  1991  42309.38         NaN
# 2     AUS    AVWAGE     TOT     USD         A  1992  43173.77         NaN
# 3     AUS    AVWAGE     TOT     USD         A  1993  43578.24         NaN
# 4     AUS    AVWAGE     TOT     USD         A  1994  43873.86         NaN
# ...   ...       ...     ...     ...       ...   ...       ...         ...
# 1183  CRI    AVWAGE     TOT     USD         A  2017  25839.50         NaN
# 1184  CRI    AVWAGE     TOT     USD         A  2018  26764.21         NaN
# 1185  CRI    AVWAGE     TOT     USD         A  2019  27875.20         NaN
# 1186  CRI    AVWAGE     TOT     USD         A  2020  30658.30         NaN
# 1187  CRI    AVWAGE     TOT     USD         A  2021  30499.41         NaN
#
# [1188 rows x 8 columns]

# %%
master = master.merge(life,on=['ISO3','year'],how='left')

# %%
master=master.merge(money,on=['ISO3','year'],how='left')

# %%
master=master.merge(work,on=['ISO3','year'],how='left')

# %%
#master=master.merge(happines,on=['ISO3','year'])

# %%
master
# Out:
#       Country name_x Alpha-2 code ISO3  Numeric code  latitude  longitude
# 0        Afghanistan           AF  AFG             4      33.0       65.0  \
# 1        Afghanistan           AF  AFG             4      33.0       65.0
# 2        Afghanistan           AF  AFG             4      33.0       65.0
# 3        Afghanistan           AF  AFG             4      33.0       65.0
# 4        Afghanistan           AF  AFG             4      33.0       65.0
# ...              ...          ...  ...           ...       ...        ...
# 16123       Zimbabwe           ZW  ZWE           716     -20.0       30.0
# 16124       Zimbabwe           ZW  ZWE           716     -20.0       30.0
# 16125       Zimbabwe           ZW  ZWE           716     -20.0       30.0
# 16126       Zimbabwe           ZW  ZWE           716     -20.0       30.0
# 16127       Zimbabwe           ZW  ZWE           716     -20.0       30.0
#
#        year Country name_y  Healthy life expectancy at birth INDICATOR_x  ...
# ...

# %%
master.sort_values(['year', 'ISO3'], inplace=True)

# %%
master.to_csv('newmaster.csv')

# %%
import pandas as pd

# Load the CSV data into DataFrames
df_master = pd.read_csv('data/')
df_additional = pd.read_csv('additional_data.csv')

# %%
# Sort the main DataFrame by year and country
df_master.sort_values(['year', 'country'], inplace=True)

# %%
# Merge the data on 'year' and 'country' columns, keeping all rows
df_merged = pd.merge(df_master, df_additional, on=['year', 'country'], how='left')

# %%
# Forward fill missing values with data from the previous year
df_merged.fillna(method='ffill', inplace=True)

# %%
# Display the merged DataFrame
print(df_merged)
